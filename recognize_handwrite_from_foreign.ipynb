# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
mnist = input_data.read_data_sets("MNIST_data",one_hot=True)
n_nodes_hl1 = 500
n_nodes_hl2= 500
n_nodes_hl3= 500

n_classes = 10
batch_size = 100

x = tf.placeholder('float',[None,784])
y = tf.placeholder('float')

def neural_network_model(data):
    hidden_1_layer = {'weights':tf.Variable(tf.random_normal([784,n_nodes_hl1])),
                     'baises':tf.Variable(tf.random_normal([n_nodes_hl1]))}
    
    hidden_2_layer = {'weights':tf.Variable(tf.random_normal([n_nodes_hl1,n_nodes_hl2])),
                     'baises':tf.Variable(tf.random_normal([n_nodes_hl1]))}
    
    hidden_3_layer = {'weights':tf.Variable(tf.random_normal([n_nodes_hl2,n_nodes_hl3])),
                     'baises':tf.Variable(tf.random_normal([n_nodes_hl1]))}
    
    output_layer = {'weights':tf.Variable(tf.random_normal([n_nodes_hl3,n_classes])),
                     'baises':tf.Variable(tf.random_normal([n_classes]))}
    
    
    l1 = tf.add(tf.matmul(data,hidden_1_layer['weights']) , hidden_1_layer['baises'])
    l1 = tf.nn.relu(l1)
    
    l2 = tf.add(tf.matmul(l1,hidden_2_layer['weights']) , hidden_2_layer['baises'])
    l2 = tf.nn.relu(l2)
    
    l3 = tf.add(tf.matmul(l2,hidden_3_layer['weights']) , hidden_3_layer['baises'])
    l3 = tf.nn.relu(l3)
    
    output = tf.matmul(l3,output_layer['weights']) + output_layer['baises']
    
    return output


def train_neural_network(x):
    prediction = neural_network_model(x)
    cost = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(labels=y,logits=prediction))
    optimizer = tf.train.AdamOptimizer(0.001).minimize(cost)
    
    hm_epochs = 10
    
    with tf.Session() as sess:
        sess.run(tf.initialize_all_variables())
        
        for epoch in range(hm_epochs):
            epoch_loss = 0
            for _ in range(int(mnist.train.num_examples/batch_size)):
                epoch_x,epoch_y = mnist.train.next_batch(batch_size)
                
                _,c = sess.run([optimizer,cost],feed_dict = {x: epoch_x, y: epoch_y})
                epoch_loss += c
                
            print('epoch',epoch,'completed out of',hm_epochs,'loss:',epoch_loss,'cost:',cost)
            correct = tf.equal(tf.argmax(prediction,1),tf.arg_max(y,1))
        
            accuracy = tf.reduce_mean(tf.cast(correct,'float'))
            
            print('Accuracy:',accuracy.eval({x:mnist.test.images,y:mnist.test.labels}))
        
        
        
       
        
        
train_neural_network(x)
# Out:
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# epoch 0 completed out of 10 loss: 1765458.4631958008 cost: Tensor("Mean_3:0", shape=(), dtype=float32)
# Accuracy: 0.8972
# epoch 1 completed out of 10 loss: 387773.06786346436 cost: Tensor("Mean_3:0", shape=(), dtype=float32)
# Accuracy: 0.9192
# epoch 2 completed out of 10 loss: 213984.08845949173 cost: Tensor("Mean_3:0", shape=(), dtype=float32)
# Accuracy: 0.9318
# epoch 3 completed out of 10 loss: 123810.48119837165 cost: Tensor("Mean_3:0", shape=(), dtype=float32)
# Accuracy: 0.9414
# epoch 4 completed out of 10 loss: 75161.83558289707 cost: Tensor("Mean_3:0", shape=(), dtype=float32)
# Accuracy: 0.9403
# epoch 5 completed out of 10 loss: 49153.937554970384 cost: Tensor("Mean_3:0", shape=(), dtype=float32)
# Accuracy: 0.9407
# epoch 6 completed out of 10 loss: 33756.449386198634 cost: Tensor("Mean_3:0", shape=(), dtype=float32)
# Accuracy: 0.949
# epoch 7 completed out of 10 loss: 24677.5294213742 cost: Tensor("Mean_3:0", shape=(), dtype=float32)
# Accuracy: 0.9503
# epoch 8 completed out of 10 loss: 21349.53938333597 cost: Tensor("Mean_3:0", shape=(), dtype=float32)
# Accuracy: 0.9527
# epoch 9 completed out of 10 loss: 18669.853245154023 cost: Tensor("Mean_3:0", shape=(), dtype=float32)
# Accuracy: 0.9474
